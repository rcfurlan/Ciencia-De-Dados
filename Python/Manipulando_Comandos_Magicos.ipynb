# %% [markdown]
# # Comandos Mágicos do Python

# %%
# %magic

# %%
path = %pwd
print(path)
# Out:
# D:\Compartilhado

# %%
# Limpa o terminal
# %clear

# %%
# %env
# Out:
# {'ALLUSERSPROFILE': 'C:\\ProgramData',
#  'APPDATA': 'C:\\Users\\ricardo.furlan\\AppData\\Roaming',
#  'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#  'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#  'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#  'COMPUTERNAME': 'NOTE-658',
#  'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe',
#  'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
#  'DS_COMMON_DIR': 'C:\\ProgramData\\SAP BusinessObjects\\Data Services',
#  'DS_USER_DIR': 'C:\\Users\\ricardo.furlan\\AppData\\Local\\SAP\\Data Services',
#  'FPS_BROWSER_APP_PROFILE_STRING': 'Internet Explorer',
#  'FPS_BROWSER_USER_PROFILE_STRING': 'Default',
#  'HDBADONET': 'C:\\Program Files\\sap\\hdbclient\\ado.net\\',
#  'HOMEDRIVE': 'C:',
#  'HOMEPATH': '\\Users\\ricardo.furlan',
#  'LINK_DIR': 'C:\\Program Files (x86)\\SAP BusinessObjects\\Data Services',
#  'LOCALAPPDATA': 'C:\\Users\\ricardo.furlan\\AppData\\Local',
# ...

# %%
# %run comando_magico.py
# Out:
# Executado com o comando magico %run

# %%
# %time print('Executado com o comando magico %time')
# Out:
# Executado com o comando magico %time
# Wall time: 0 ns

# %%
# %timeit print('Executado com o comando magico %timeit')
# Out:
# Executado com o comando magico %timeit
# Executado com o comando magico %timeit
# Executado com o comando magico %timeit
# Executado com o comando magico %timeit
# Executado com o comando magico %timeit
# Executado com o comando magico %timeit
# Executado com o comando magico %timeit
# Executado com o comando magico %timeit
# Executado com o comando magico %timeit
# Executado com o comando magico %timeit
# Executado com o comando magico %timeit
# Executado com o comando magico %timeit
# Executado com o comando magico %timeit
# Executado com o comando magico %timeit
# Executado com o comando magico %timeit
# Executado com o comando magico %timeit
# Executado com o comando magico %timeit
# Executado com o comando magico %timeit
# Executado com o comando magico %timeit
# Executado com o comando magico %timeit
# Executado com o comando magico %timeit
# Executado com o comando magico %timeit
# Executado com o comando magico %timeit
# Executado com o comando magico %timeit
# ...

# %%
# %load comando_magico.py

print('Executado com o comando magico %run')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
plt.plot(np.random.randn(50).cumsum())

# %% [markdown]
# <img src="machine-learning-Call-Center-Magazine.jpg"/>

# %%
# %%html
# <iframe width="650" height="406" src="https://www.youtube.com/embed/pgEfZvJjbZg" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="650" height="406" src="https://www.youtube.com/embed/pgEfZvJjbZg" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# # Temas do jupyter notebook
#
# :\ pip install jupyterthemes
#
# :\ jt -l (verifica os temas instalados)
#
# :\ Available Themes:
#
#    chesterish
#
#    grade3
#
#    gruvboxd
#
#    gruvboxl
#
#    monokai
#
#    oceans16
#
#    onedork
#
#    solarizedd
#
#    solarizedl
#
# :\ jt -t[tema]
#
# :\ jt-r (volta para o tema default do jupyter)
